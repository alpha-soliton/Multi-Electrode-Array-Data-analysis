# %%
from scipy import io

# %%
matdata = io.loadmat("../ips_spike_data/hiPS-neuron_300days_sample7.mat", squeeze_me=True)

# %%
matdata
# Out:
# {'SortedSpike': array(([array([    3998.62,     4157.62,     4266.54, ...,  1198449.98,
#          1198794.98,  1199029.1 ]), array([    4129.12,     4219.2 ,     4242.06,     4304.18,     4319.06,
#             4425.3 ,     4821.66,    12819.38,    13048.84,    17839.54,
#            23534.54,    23711.4 ,    29509.14,    29601.56,    29619.4 ,
#            29681.5 ,    29740.64,    34962.18,    34967.22,    34987.22,
#            35107.04,    35667.84,    41987.56,    42393.84,    42820.48,
#            47248.1 ,    53294.66,    53330.08,    53370.76,    53397.82,
#            59145.3 ,    59161.2 ,    59176.66,    59203.58,    59208.76,
#            59251.74,    59370.84,    64552.28,    67798.5 ,    73470.5 ,
#            74020.14,    74172.82,    80272.16,    80281.6 ,    80710.24,
#            85066.74,    89251.86,    89266.68,    89276.56,    89308.82,
#            89479.68,    89548.58,    89661.5 ,    95085.82,   101133.4 ,
# ...
